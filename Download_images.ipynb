# %%
# !pip install deepface
# !pip install genderize
# !pip install ethnicolr
# !pip install face-recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 38.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.6 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=62c8bef9561b42e0304c5d07aced690e7beca8033f5c40260e3373089587506c
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/MODS207/
# Out:
# /content/drive/MyDrive/MODS207

# %%
data = pd.read_csv('0_9999.csv', header=0, index_col=None)

# %%
data['name'].isnull().values.any()
# Out:
# False

# %%
data['image'].isnull().values.any()
# Out:
# False

# %%
import requests # request img from web
import shutil # save img locally

# %%
for i in range(10000):
    url = data.iloc[i]['image']
    file_name = 'Image/' + str(i) + '.jpg'

    res = requests.get(url, stream = True)

    if res.status_code == 200:
        with open(file_name,'wb') as f:
            shutil.copyfileobj(res.raw, f)
        print('Image sucessfully Downloaded: ',file_name)
    else:
        print('Image Couldn\'t be retrieved')
# Out:
# Streaming output truncated to the last 5000 lines.
# Image sucessfully Downloaded:  Image/540.jpg
# Image sucessfully Downloaded:  Image/541.jpg
# Image sucessfully Downloaded:  Image/542.jpg
# Image sucessfully Downloaded:  Image/543.jpg
# Image sucessfully Downloaded:  Image/544.jpg
# Image sucessfully Downloaded:  Image/545.jpg
# Image sucessfully Downloaded:  Image/546.jpg
# Image sucessfully Downloaded:  Image/547.jpg
# Image sucessfully Downloaded:  Image/548.jpg
# Image sucessfully Downloaded:  Image/549.jpg
# Image sucessfully Downloaded:  Image/550.jpg
# Image sucessfully Downloaded:  Image/551.jpg
# Image sucessfully Downloaded:  Image/552.jpg
# Image sucessfully Downloaded:  Image/553.jpg
# Image sucessfully Downloaded:  Image/554.jpg
# Image sucessfully Downloaded:  Image/555.jpg
# Image sucessfully Downloaded:  Image/556.jpg
# Image sucessfully Downloaded:  Image/557.jpg
# Image sucessfully Downloaded:  Image/558.jpg
# Image sucessfully Downloaded:  Image/559.jpg
# ...

# %%
i = 0
a = 'Image/' + str(i) + '.jpg'
print(a)
# Out:
# Image/0.jpg

# %%
genderize_reply = []

# %%
from genderize import Genderize
# Out:
# ---------------------------------------------------------------------------
# GenderizeException                        Traceback (most recent call last)
# <ipython-input-22-64ea30233455> in <cell line: 2>()
#       1 from genderize import Genderize
# ----> 2 print(Genderize().get(data['name'].values.tolist()))
#
# /usr/local/lib/python3.10/dist-packages/genderize/__init__.py in get(self, names, country_id, language_id, retheader)
#      94         :raises GenderizeException: if API server returns HTTP error code.
#      95         """
# ---> 96         responses = [
#      97             self._get_chunk(name_chunk, country_id, language_id)
#      98             for name_chunk
#
# /usr/local/lib/python3.10/dist-packages/genderize/__init__.py in <listcomp>(.0)
#      95         """
#      96         responses = [
# ---> 97             self._get_chunk(name_chunk, country_id, language_id)
#      98             for name_chunk
# ...

# %%
for i in (0, 10000, 1000):
    print(i)
    name = data['name'].iloc[i: i + 500].values.tolist()
    genderize_reply.append(Genderize().get(name))
    time.sleep(5)
# Out:
# 0
# ---------------------------------------------------------------------------
# GenderizeException                        Traceback (most recent call last)
# <ipython-input-35-f05ba2ed30e3> in <cell line: 1>()
#       2     print(i)
#       3     name = data['name'].iloc[i: i + 500].values.tolist()
# ----> 4     genderize_reply.append(Genderize().get(name))
#       5     time.sleep(5)
#
# /usr/local/lib/python3.10/dist-packages/genderize/__init__.py in get(self, names, country_id, language_id, retheader)
#      94         :raises GenderizeException: if API server returns HTTP error code.
#      95         """
# ---> 96         responses = [
#      97             self._get_chunk(name_chunk, country_id, language_id)
#      98             for name_chunk
#
# /usr/local/lib/python3.10/dist-packages/genderize/__init__.py in <listcomp>(.0)
#      95         """
#      96         responses = [
# ---> 97             self._get_chunk(name_chunk, country_id, language_id)
# ...

# %%
genderize_reply
# Out:
# [['Harjinder',
#   'Taylor',
#   'John',
#   'Andrew',
#   'Stephanie',
#   'Aziz Ibrahim',
#   'Andrea',
#   'Tami',
#   'Stefanie',
#   'Kj',
#   'Matthew',
#   'Morgan',
#   'Steven',
#   'Adrian',
#   'Brianna',
#   'Lori',
#   'Laura',
#   'M',
#   'Catherine',
#   'Emily',
#   'Tatsuya',
#   'Cara',
#   'Anna',
#   'Erica',
#   'Pelle',
#   'Jay',
#   'Daniel',
#   'Bradi',
#   'Shayne',
#   'David',
#   'Jason',
#   'Jason',
#   'Ezra',
#   'Eric',
#   'Claire',
#   'Barbara',
#   'Kathy',
#   'Sasha',
#   'Sami',
#   'Julia',
#   'Dave',
#   'Kendyl',
#   'Alan',
#   'Jolie',
#   'Jordan',
#   'Grisel',
#   'Megan',
#   'Anna',
#   'Chlóe',
#   'Stefano',
#   'Paula',
#   'Laura',
#   'D',
#   'Shayla',
#   'Fran',
#   'Nico',
#   'Melissa',
#   'Sofia',
#   'Shannon',
#   'Alaina',
#   'Bastien',
#   'Bastien',
#   'Michael',
#   'Jessica',
#   'Meridith',
#   'Juo',
#   'Maria',
#   'Molly',
#   'Lucas',
#   'Nicolà',
#   'Mary',
#   'Tobias',
#   'Megan',
#   'Simon',
# ...

# %%
 a = Genderize().get(['James'])

# %%
import face_recognition
image = face_recognition.load_image_file("Image/2.jpg")
face_locations = face_recognition.face_locations(image)

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

image = mpimg.imread("Image/2.jpg")
plt.imshow(image)

# %%
face = face_locations[0]

# %%
face_locations
# Out:
# [(247, 632, 632, 247)]

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
demo_img_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
cv2_imshow('bgr', image)
cv2_imshow('rgb', demo_img_rgb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-45a3fb47bef8> in <cell line: 2>()
#       1 demo_img_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
# ----> 2 cv2_imshow('bgr', image)
#       3 cv2_imshow('rgb', demo_img_rgb)
#
# TypeError: cv2_imshow() takes 1 positional argument but 2 were given

# %%
copy = demo_img_rgb.copy()

# %%
face
# Out:
# (247, 632, 632, 247)

# %%
cv2.rectangle(copy, (face[3], face[0]),(face[1], face[2]), (255,0,255), 2)
cv2_imshow(copy)
#cv2.imshow('OBAMA',obama_img_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=901x901 at 0x7FC7BCA15690>

# %%
cv2_imshow(copy[face[3]:face[1],face[0]:face[2]])
# Out:
# <PIL.Image.Image image mode=RGB size=385x385 at 0x7FC7248B48B0>

# %%
cv2_imshow
# Out:
# <function google.colab.patches.cv2_imshow(a)>

# %%
cv2_imshow(demo_img_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=901x901 at 0x7FC7E6D83460>

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
objs = DeepFace.analyze(img_path = "Image/2.jpg",
        actions = ['gender', 'race']
)
# Out:
# Action: race: 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]

# %%
objs
# Out:
# [{'gender': {'Woman': 0.0017897955331136473, 'Man': 99.99821186065674},
#   'dominant_gender': 'Man',
#   'region': {'x': 261, 'y': 187, 'w': 408, 'h': 408},
#   'race': {'asian': 1.6517270190474775e-09,
#    'indian': 3.680362958835559e-08,
#    'black': 1.7514546128520603e-11,
#    'white': 99.98052716255188,
#    'middle eastern': 0.011713936692103744,
#    'latino hispanic': 0.007765791815472767},
#   'dominant_race': 'white'}]

# %%
objs[0]['gender']['Man']
# Out:
# 99.99821186065674
